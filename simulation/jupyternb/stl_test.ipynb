# %%
# %matplotlib widget
import numpy as np
from stl import mesh
import matplotlib.pyplot as plt

# %%
piste = mesh.Mesh.from_file('piste.stl')

# %%
from mpl_toolkits import mplot3d
figure = plt.figure()
axes = figure.add_subplot(projection='3d')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(piste.vectors))
scale = your_mesh.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
subset = piste.vectors[(piste.normals[:, 0] == 0.0) & (piste.normals[:, 1] == 0.0) & (piste.normals[:, 2] < 0.0)]

# %%
from mpl_toolkits import mplot3d
figure = plt.figure()
axes = figure.add_subplot(projection='3d')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(subset))
scale = your_mesh.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
subset.shape
# Out:
# (880, 3, 3)

# %%
subset[:,:, 0:2][0]
# Out:
# array([[-30.711607, 117.08541 ],
#        [-37.524292, 109.765076],
#        [-39.488426, 111.68677 ]], dtype=float32)

# %%
from matplotlib.patches import Polygon

fig,ax = plt.subplots()
for y in subset[:,:, 0:2]:
    p = Polygon(y, facecolor = 'k')
    ax.add_patch(p)
ax.axis('equal')
# Out:
# (-205.49288635253907, 905.4996612548828, -32.99992065429687, 582.9983337402343)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
